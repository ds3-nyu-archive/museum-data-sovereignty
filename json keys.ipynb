# %%
import json

#loading sample of notice of inventory completion json
inventory_json = json.loads('{"abstract":null,"action":"Notice","agencies":[{"raw_name":"DEPARTMENT OF THE INTERIOR","name":"Interior Department","id":253,"url":"https://www.federalregister.gov/agencies/interior-department","json_url":"https://www.federalregister.gov/api/v1/agencies/253.json","parent_id":null,"slug":"interior-department"},{"raw_name":"National Park Service","name":"National Park Service","id":362,"url":"https://www.federalregister.gov/agencies/national-park-service","json_url":"https://www.federalregister.gov/api/v1/agencies/362.json","parent_id":253,"slug":"national-park-service"}],"body_html_url":"https://www.federalregister.gov/documents/full_text/html/1997/05/22/97-13463.html","cfr_references":[],"citation":"62 FR 28063","comment_url":null,"comments_close_on":null,"correction_of":null,"corrections":[],"dates":null,"disposition_notes":null,"docket_ids":[],"document_number":"97-13463","effective_on":null,"end_page":28064,"executive_order_notes":null,"executive_order_number":null,"full_text_xml_url":null,"html_url":"https://www.federalregister.gov/documents/1997/05/22/97-13463/notice-of-inventory-completion-for-native-american-human-remains-from-lamoine-me-in-the-possession","images":{},"json_url":"https://www.federalregister.gov/api/v1/documents/97-13463.json?publication_date=1997-05-22","mods_url":"https://www.govinfo.gov/metadata/granule/FR-1997-05-22/97-13463/mods.xml","page_length":2,"page_views":{"count":19,"last_updated":"2020-02-06 20:15:10 -0500"},"pdf_url":"https://www.govinfo.gov/content/pkg/FR-1997-05-22/pdf/97-13463.pdf","presidential_document_number":null,"proclamation_number":null,"public_inspection_pdf_url":null,"publication_date":"1997-05-22","raw_text_url":"https://www.federalregister.gov/documents/full_text/text/1997/05/22/97-13463.txt","regulation_id_number_info":{},"regulation_id_numbers":[],"regulations_dot_gov_info":{},"regulations_dot_gov_url":null,"significant":null,"signing_date":null,"start_page":28063,"subtype":null,"title":"Notice of Inventory Completion for Native American Human Remains From Lamoine, ME, in the Possession of Robert S. Peabody Museum of Archaeology, Andover, ME","toc_doc":null,"toc_subject":null,"topics":[],"type":"Notice","volume":62}')

#loading sample of notice of intent to repatriate json
repatriate_json = json.loads('{"abstract":"The Arizona State Museum, University of Arizona has corrected an inventory of unassociated funerary objects, published in a Notice of Intent to Repatriate Cultural Items in the Federal Register on September 10, 2014. This notice corrects the number of unassociated funerary objects. Lineal descendants or representatives of any Indian Tribe or Native Hawaiian organization not identified in this notice that wish to claim these cultural items should submit a written request to the Arizona State Museum, University of Arizona. If no additional claimants come forward, transfer of control of the cultural items to the lineal descendants, Indian Tribes, or Native Hawaiian organizations stated in this notice may proceed.","action":"Notice; correction.","agencies":[{"raw_name":"DEPARTMENT OF THE INTERIOR","name":"Interior Department","id":253,"url":"https://www.federalregister.gov/agencies/interior-department","json_url":"https://www.federalregister.gov/api/v1/agencies/253.json","parent_id":null,"slug":"interior-department"},{"raw_name":"National Park Service","name":"National Park Service","id":362,"url":"https://www.federalregister.gov/agencies/national-park-service","json_url":"https://www.federalregister.gov/api/v1/agencies/362.json","parent_id":253,"slug":"national-park-service"}],"body_html_url":"https://www.federalregister.gov/documents/full_text/html/2019/08/05/2019-16689.html","cfr_references":[],"citation":"84 FR 38053","comment_url":null,"comments_close_on":null,"correction_of":null,"corrections":[],"dates":"Lineal descendants or representatives of any Indian Tribe or Native Hawaiian organization not identified in this notice that wish to claim these cultural items should submit a written request with information in support of the claim to the Arizona State Museum,","disposition_notes":null,"docket_ids":["NPS-WASO-NAGPRA-NPS0028458","PPWOCRADN0-PCU00RP14.R50000"],"document_number":"2019-16689","effective_on":null,"end_page":38053,"executive_order_notes":null,"executive_order_number":null,"full_text_xml_url":"https://www.federalregister.gov/documents/full_text/xml/2019/08/05/2019-16689.xml","html_url":"https://www.federalregister.gov/documents/2019/08/05/2019-16689/notice-of-intent-to-repatriate-cultural-items-arizona-state-museum-university-of-arizona-tucson-az","images":{},"json_url":"https://www.federalregister.gov/api/v1/documents/2019-16689.json?publication_date=2019-08-05","mods_url":"https://www.govinfo.gov/metadata/granule/FR-2019-08-05/2019-16689/mods.xml","page_length":1,"page_views":{"count":63,"last_updated":"2020-02-09 18:15:10 -0500"},"pdf_url":"https://www.govinfo.gov/content/pkg/FR-2019-08-05/pdf/2019-16689.pdf","presidential_document_number":null,"proclamation_number":null,"public_inspection_pdf_url":"https://s3.amazonaws.com/public-inspection.federalregister.gov/2019-16689.pdf?1564749925","publication_date":"2019-08-05","raw_text_url":"https://www.federalregister.gov/documents/full_text/text/2019/08/05/2019-16689.txt","regulation_id_number_info":{},"regulation_id_numbers":[],"regulations_dot_gov_info":{},"regulations_dot_gov_url":null,"significant":null,"signing_date":null,"start_page":38053,"subtype":null,"title":"Notice of Intent To Repatriate Cultural Items: Arizona State Museum, University of Arizona, Tucson, AZ; Correction","toc_doc":"Arizona State Museum, University of Arizona, Tucson, AZ; Correction","toc_subject":"Repatriation of Cultural Items:","topics":[],"type":"Notice","volume":84}')

#recursive function to print all levels of json keys
def print_keys(json_dict, tabs):
    for key, value in json_dict.items():
        print(tabs*'\t' + key)
        if type(value)==list:
            print((tabs+1)*'\t', 'SUB-KEYS:')
            for x in value:
                if type(x)==dict: 
                    print_keys(x, tabs+1)
                    
print('SAMPLE OF NOTICE OF INVENTORY COMPLETION')            
print_keys(inventory_json, 0)
print('\n')
print('SAMPLE OF NOTICE OF INTENT TO REPATRIATE')    
print_keys(repatriate_json, 0)
# Out:
# SAMPLE OF NOTICE OF INVENTORY COMPLETION
# abstract
# action
# agencies
# 	 SUB-KEYS:
# 	raw_name
# 	name
# 	id
# 	url
# 	json_url
# 	parent_id
# 	slug
# 	raw_name
# 	name
# 	id
# 	url
# 	json_url
# 	parent_id
# 	slug
# body_html_url
# cfr_references
# 	 SUB-KEYS:
# citation
# comment_url
# comments_close_on
# correction_of
# corrections
# 	 SUB-KEYS:
# dates
# disposition_notes
# docket_ids
# 	 SUB-KEYS:
# document_number
# effective_on
# end_page
# executive_order_notes
# executive_order_number
# full_text_xml_url
# html_url
# images
# json_url
# mods_url
# page_length
# page_views
# pdf_url
# presidential_document_number
# proclamation_number
# public_inspection_pdf_url
# publication_date
# raw_text_url
# regulation_id_number_info
# regulation_id_numbers
# 	 SUB-KEYS:
# regulations_dot_gov_info
# regulations_dot_gov_url
# significant
# signing_date
# start_page
# subtype
# title
# toc_doc
# toc_subject
# topics
# 	 SUB-KEYS:
# type
# volume
#
#
# ...

# %%
#printing values which may provide a way to access full text
print(inventory_json['html_url'])
print(inventory_json['full_text_xml_url'])
print(inventory_json['raw_text_url'])
# Out:
# https://www.federalregister.gov/documents/1997/05/22/97-13463/notice-of-inventory-completion-for-native-american-human-remains-from-lamoine-me-in-the-possession
# None
# https://www.federalregister.gov/documents/full_text/text/1997/05/22/97-13463.txt

# %%
#printing values which may provide a way to access full text
print(repatriate_json['html_url'])
print(repatriate_json['full_text_xml_url'])
print(repatriate_json['raw_text_url'])
# Out:
# https://www.federalregister.gov/documents/2019/08/05/2019-16689/notice-of-intent-to-repatriate-cultural-items-arizona-state-museum-university-of-arizona-tucson-az
# https://www.federalregister.gov/documents/full_text/xml/2019/08/05/2019-16689.xml
# https://www.federalregister.gov/documents/full_text/text/2019/08/05/2019-16689.txt
